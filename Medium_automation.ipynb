# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasdasu24/Automation/blob/master/Medium_automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests
from bs4 import BeautifulSoup

# %%
headers = {
    'authority': 'medium.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'none',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '_ga=GA1.2.210810033.1625120447; g_state={"i_p":1632563953180,"i_l":4}; ext_name=ojplmecpdpgccookcobabopnaifgidhf; uid=1556949f4866; sid=1:pcTncp/CXXfmojWNZ4q8TirwESQUCkjAcdDmxNmpNf8k3YbdB5uXtlPVmZOBb2fx; optimizelyEndUserId=1556949f4866; nonce=1S1eCrug; lightstep_guid/medium-web=3cc34e131f079169; lightstep_session_id=85c9834b02a59f30; sz=1833; pr=1; tz=-330; xsrf=190986197c22; _gid=GA1.2.1009435824.1639977359; __cfruid=26aaa9af918fd089c489153f20c16cda617e555a-1639979007; _dd_s=rum=0&expire=1639982327646; _gat=1'
    }


html_response = requests.get('https://medium.com/me/stats/post/6a8875a9fa7d', headers=headers)

# %%
soup = BeautifulSoup(html_response.text)

# %%
views = ''
earnings = ''
for i in soup.find_all('p'):
    if 'Views' in i.text:
        views =  i.find_next('h2').getText()
    elif 'Earnings' in i.text:
        earnings =  i.find_next('h2').getText()

# %%
views
# Out:
# '9.7K'

# %%
payout = soup.select('div.lx.t.ly.ai.kk.jk.lz')
article_stats = {}
name = soup.select('div.ap.l.kr')
article_stats['Article_Name'] = name[0].text

# %%
article_stats
# Out:
# {'Article_Name': 'Power BI vs Tableau\u200a—\u200aWhich one is better? (The analyst perspective)'}

# %%
views = ''
earnings = ''
reading = ''
for i in soup.find_all('p'):
    if 'Views' in i.text:
        views =  i.find_next('h2').getText()
    elif 'Earnings' in i.text:
        earnings =  i.find_next('h2').getText()
    elif 'Average Reading' in i.text:
        reading =  i.find_next('h2').getText()

# %%
print(views, earnings, reading)
# Out:
# 9.7K $99.20 4 min 43 sec

# %%
for line in payout[0]:
        if 'Views' in line.text:
            article_stats['views'] = line.text.split('Views')[1]
        elif 'Earnings' in line.text:
            article_stats['earnings'] = line.text.split('Earnings')[1]
        elif 'Average Reading' in line.text:
            article_stats['average_reading_time'] = line.text.split('Avg Reading Time')[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-70444ebf0074> in <module>()
# ----> 1 for line in payout[0]:
#       2         if 'Views' in line.text:
#       3             article_stats['views'] = line.text.split('Views')[1]
#       4         elif 'Earnings' in line.text:
#       5             article_stats['earnings'] = line.text.split('Earnings')[1]
#
# IndexError: list index out of range

# %%
article_stats
# Out:
# {'Article_Name': '6 Web-series Based on AI You Should Binge-Watch Today If You Are an AI Enthusiast [Updated List]',
#  'average_reading_time': '2 min 39 sec',
#  'earnings': '$2.85',
#  'views': '657'}

# %%
impact = soup.select('div.l.ox.g')
for line in impact:
  for li in line:
    for l in li:
      if 'Views' in l.get_text():
        article_stats['Lifetime Views'] = l.get_text().split('Lifetime Views')[1].split('Internal Views')[0]
        article_stats['Internal Views'] = l.get_text().split('Internal Views')[1].split('External Views')[0]
        article_stats['External Views'] = l.get_text().split('External Views')[1]
      elif 'Lifetime Earnings' in l.get_text():
        article_stats['lifetime Earnings'] = l.get_text().split('Lifetime Earnings')[1]
      elif 'Member reading time' in l.get_text():
        article_stats['Lifetime member reading time'] = l.get_text().split('Lifetime member reading time')[1]

# %%
impact
# Out:
# []

# %%
print(soup.select('div.mv.ae.t.u'))
# Out:
# [<div class="mv ae t u"><div class="ae t kh u ic"><div class="ae t u m n o mw"><span class="iq">Loading...</span></div></div></div>]

# %%
print(soup.find('div', {'class': 'nf gb oa t kh nh ni nj nk nl ai'}))
# Out:
# None

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
headers = {
    'authority': 'medium.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'apollographql-client-name': 'lite',
    'medium-frontend-route': 'stats-post',
    'ot-tracer-sampled': 'true',
    'sec-ch-ua-mobile': '?0',
    'ot-tracer-traceid': '3834854332da7e3e',
    'medium-frontend-path': '/me/stats/post/a3f3ed9d1f1e',
    'graphql-operation': 'StatsPostReferrersContainer',
    'content-type': 'application/json',
    'accept': '*/*',
    'ot-tracer-spanid': '261db0451788ada1',
    'medium-frontend-app': 'lite/main-20211210-232626-79d0eb6cc9',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'apollographql-client-version': 'main-20211210-232626-79d0eb6cc9',
    'sec-ch-ua-platform': '"Windows"',
    'origin': 'https://medium.com',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://medium.com/me/stats/post/a3f3ed9d1f1e',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '_ga=GA1.2.210810033.1625120447; g_state={"i_p":1632563953180,"i_l":4}; ext_name=ojplmecpdpgccookcobabopnaifgidhf; uid=1556949f4866; sid=1:pcTncp/CXXfmojWNZ4q8TirwESQUCkjAcdDmxNmpNf8k3YbdB5uXtlPVmZOBb2fx; optimizelyEndUserId=1556949f4866; nonce=1S1eCrug; lightstep_guid/medium-web=3cc34e131f079169; lightstep_session_id=85c9834b02a59f30; sz=1833; pr=1; tz=-330; xsrf=190986197c22; _gid=GA1.2.1009435824.1639977359; __cfruid=26aaa9af918fd089c489153f20c16cda617e555a-1639979007; dd_cookie_test_14a673ca-0d1a-4a8e-bfd9-4f1c3d7bc5c6=test; _dd_s=rum=0&expire=1639983189541; dd_cookie_test_ee1491a9-aab2-46a5-b567-f8af9eaebeeb=test; dd_cookie_test_949adad5-dcd9-4a0e-b6fe-72d6a62f004f=test'}

#data = '[{"operationName":"StatsPostReferrersContainer","variables":{"postId":"170e63773708"},"query":"query StatsPostReferrersContainer($postId: ID!) {\\n  post(id: $postId) {\\n    id\\n    ...StatsPostReferrersExternalRow_post\\n    referrers {\\n      ...StatsPostReferrersContainer_referrers\\n      __typename\\n    }\\n    totalStats {\\n      views\\n      __typename\\n    }\\n    __typename\\n  }\\n}\\n\\nfragment StatsPostReferrersExternalRow_post on Post {\\n  title\\n  __typename\\n  id\\n}\\n\\nfragment StatsPostReferrersContainer_referrers on Referrer {\\n  postId\\n  sourceIdentifier\\n  totalCount\\n  type\\n  internal {\\n    postId\\n    collectionId\\n    profileId\\n    type\\n    __typename\\n  }\\n  search {\\n    domain\\n    keywords\\n    __typename\\n  }\\n  site {\\n    href\\n    title\\n    __typename\\n  }\\n  platform\\n  __typename\\n}\\n"}]'
data = '[{"operationName":"StatsPostReferrersContainer","variables":{"postId":"a3f3ed9d1f1e"},"query":"query StatsPostReferrersContainer($postId: ID!) {\n  post(id: $postId) {\n    id\n    ...StatsPostReferrersExternalRow_post\n    referrers {\n      ...StatsPostReferrersContainer_referrers\n      __typename\n    }\n    totalStats {\n      views\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment StatsPostReferrersExternalRow_post on Post {\n  title\n  __typename\n  id\n}\n\nfragment StatsPostReferrersContainer_referrers on Referrer {\n  postId\n  sourceIdentifier\n  totalCount\n  type\n  internal {\n    postId\n    collectionId\n    profileId\n    type\n    __typename\n  }\n  search {\n    domain\n    keywords\n    __typename\n  }\n  site {\n    href\n    title\n    __typename\n  }\n  platform\n  __typename\n}\n"}]'
response = requests.post('https://medium.com/_/graphql', headers=headers, data=data)

# %%
print(response)
# Out:
# <Response [400]>

# %%
header = {
    'content-type': 'application/json',
'cookie': '_ga=GA1.2.210810033.1625120447; g_state={"i_p":1632563953180,"i_l":4}; ext_name=ojplmecpdpgccookcobabopnaifgidhf; uid=1556949f4866; sid=1:pcTncp/CXXfmojWNZ4q8TirwESQUCkjAcdDmxNmpNf8k3YbdB5uXtlPVmZOBb2fx; optimizelyEndUserId=1556949f4866; nonce=1S1eCrug; lightstep_guid/medium-web=3cc34e131f079169; lightstep_session_id=85c9834b02a59f30; sz=1833; pr=1; tz=-330; xsrf=190986197c22; _gid=GA1.2.1009435824.1639977359; __cfruid=26aaa9af918fd089c489153f20c16cda617e555a-1639979007; dd_cookie_test_14a673ca-0d1a-4a8e-bfd9-4f1c3d7bc5c6=test; _dd_s=rum=0&expire=1639983189541; dd_cookie_test_ee1491a9-aab2-46a5-b567-f8af9eaebeeb=test; dd_cookie_test_949adad5-dcd9-4a0e-b6fe-72d6a62f004f=test',
'graphql-operation': 'StatsPostReferrersContainer',
'medium-frontend-app': 'lite/main-20211217-235701-07ca44b735',
'medium-frontend-path': '/me/stats/post/a3f3ed9d1f1e',
'medium-frontend-route': 'stats-post',
'authority': 'medium.com',
'apollographql-client-name': 'lite',
'accept': '*/*',
'ot-tracer-sampled': 'true',
'ot-tracer-spanid': '261db0451788ada1',
'ot-tracer-traceid': '3834854332da7e3e',
'referer': 'https://medium.com/me/stats/post/a3f3ed9d1f1e',
'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
'sec-ch-ua-mobile': '?0',
'sec-ch-ua-platform': '"Linux"',
'sec-fetch-dest': 'empty',
'accept-language': 'en-US,en;q=0.9',
'sec-fetch-mode': 'cors',
'sec-fetch-site': 'same-origin',
'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
}
data = '[{"operationName":"StatsPostReferrersContainer","variables":{"postId":"a3f3ed9d1f1e"},"query":"query StatsPostReferrersContainer($postId: ID!) {\n  post(id: $postId) {\n    id\n    ...StatsPostReferrersExternalRow_post\n    referrers {\n      ...StatsPostReferrersContainer_referrers\n      __typename\n    }\n    totalStats {\n      views\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment StatsPostReferrersExternalRow_post on Post {\n  title\n  __typename\n  id\n}\n\nfragment StatsPostReferrersContainer_referrers on Referrer {\n  postId\n  sourceIdentifier\n  totalCount\n  type\n  internal {\n    postId\n    collectionId\n    profileId\n    type\n    __typename\n  }\n  search {\n    domain\n    keywords\n    __typename\n  }\n  site {\n    href\n    title\n    __typename\n  }\n  platform\n  __typename\n}\n"}]'
response = requests.post('https://medium.com/_/graphql', headers=header, data=data)

# %%
print(response)
# Out:
# <Response [400]>

# %%
headers = {
    'authority': 'medium.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'apollographql-client-name': 'lite',
    'medium-frontend-route': 'stats-post',
    'sec-ch-ua-mobile': '?0',
    'graphql-operation': 'StatsPostReferrersContainer',
    'content-type': 'application/json',
    'accept': '*/*',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'sec-ch-ua-platform': '"Linux"',
    'origin': 'https://medium.com',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '_ga=GA1.2.210810033.1625120447; g_state={"i_p":1632563953180,"i_l":4}; ext_name=ojplmecpdpgccookcobabopnaifgidhf; uid=1556949f4866; sid=1:pcTncp/CXXfmojWNZ4q8TirwESQUCkjAcdDmxNmpNf8k3YbdB5uXtlPVmZOBb2fx; optimizelyEndUserId=1556949f4866; nonce=1S1eCrug; lightstep_guid/medium-web=3cc34e131f079169; lightstep_session_id=85c9834b02a59f30; sz=1833; pr=1; tz=-330; __cfruid=25d78f52bcbd3558b725600c6ca20ae9d026b7bc-1640093648; xsrf=056857f297ec; _gid=GA1.2.1589521631.1640094626; _dd_s=rum=0&expire=1640100459963; dd_cookie_test_f1ffc9ba-0320-4b8c-9d88-a896d6511305=test',
}
post="d6b146bba03d"
data = '[{"operationName":"StatsPostReferrersContainer","variables":{"postId":"%s"},"query":"query StatsPostReferrersContainer($postId: ID!) {\\n  post(id: $postId) {\\n    id\\n    ...StatsPostReferrersExternalRow_post\\n    referrers {\\n      ...StatsPostReferrersContainer_referrers\\n      __typename\\n    }\\n    totalStats {\\n      views\\n      __typename\\n    }\\n    __typename\\n  }\\n}\\n\\nfragment StatsPostReferrersExternalRow_post on Post {\\n  title\\n  __typename\\n  id\\n}\\n\\nfragment StatsPostReferrersContainer_referrers on Referrer {\\n  postId\\n  sourceIdentifier\\n  totalCount\\n  type\\n  internal {\\n    postId\\n    collectionId\\n    profileId\\n    type\\n    __typename\\n  }\\n  search {\\n    domain\\n    keywords\\n    __typename\\n  }\\n  site {\\n    href\\n    title\\n    __typename\\n  }\\n  platform\\n  __typename\\n}\\n"}]' %(post)
response = requests.post('https://medium.com/_/graphql', headers=headers, data=data)

# %%
print(response)
# Out:
# <Response [200]>

# %%
views_bysrc = response.json()
print(views_bysrc[0]['data']['post']['title'])
print(views_bysrc[0]['data']['post']['id'])
traffic = {}
totalcount = 0
for ref in views_bysrc[0]['data']['post']['referrers']:
  traffic[ref['sourceIdentifier']] = ref['totalCount']
  totalcount += ref['totalCount']
print(traffic)
print(totalcount)
# Out:
# Understand Everything about ETL in Data Engineering- Extract, Transform, Load
# d6b146bba03d
# {'google.com': 466, 'Android device (not Medium app)': 424, 'direct': 359, 'blogs.colearninglounge.com': 251, 'androidApp': 68, 'medium.com': 13, 'medium.com/co-learning-lounge/what-is-etl-concepts-tools-pipeline-architecture-elt-d6b146bba03d': 34, 'duckduckgo.com': 5, 'www.bing.com': 2, 'netrockt.cyou': 2, 'search.yahoo.com': 1, 'wikimetrics.xyz': 1, 'keep.google.com': 1, 'switchy.io': 1, 'nixdigital.surf': 1, 'instanet.bar': 1, 'ecosia.org': 1}
# 1686

# %%
headers = {
    'authority': 'medium.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'apollographql-client-name': 'lite',
    'medium-frontend-route': 'stats-post',
    #'ot-tracer-sampled': 'true',
    'sec-ch-ua-mobile': '?0',
    #'ot-tracer-traceid': '1f5126b0c96d8fb2',
    #'medium-frontend-path': '/me/stats/post/a3f3ed9d1f1e',
    'graphql-operation': 'StatsPostChart',
    'content-type': 'application/json',
    'accept': '*/*',
    #'ot-tracer-spanid': '1eb267815fea5a23',
    #'medium-frontend-app': 'lite/main-20211221-123727-d84c13bce6',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    #'apollographql-client-version': 'main-20211221-123727-d84c13bce6',
    'sec-ch-ua-platform': '"Linux"',
    'origin': 'https://medium.com',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    #'referer': 'https://medium.com/me/stats/post/a3f3ed9d1f1e',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '_ga=GA1.2.210810033.1625120447; g_state={"i_p":1632563953180,"i_l":4}; ext_name=ojplmecpdpgccookcobabopnaifgidhf; uid=1556949f4866; sid=1:pcTncp/CXXfmojWNZ4q8TirwESQUCkjAcdDmxNmpNf8k3YbdB5uXtlPVmZOBb2fx; optimizelyEndUserId=1556949f4866; nonce=1S1eCrug; lightstep_guid/medium-web=3cc34e131f079169; lightstep_session_id=85c9834b02a59f30; sz=1833; pr=1; tz=-330; __cfruid=25d78f52bcbd3558b725600c6ca20ae9d026b7bc-1640093648; xsrf=056857f297ec; _gid=GA1.2.1589521631.1640094626; _dd_s=rum=0&expire=1640100459963; dd_cookie_test_f1ffc9ba-0320-4b8c-9d88-a896d6511305=test',
}

data = '[{"operationName":"StatsPostChart","variables":{"postId":"%s","startAt":1632873600000,"endAt":1640099559981},"query":"query StatsPostChart($postId: ID!, $startAt: Long!, $endAt: Long!) {\\n  post(id: $postId) {\\n    id\\n    ...StatsPostChart_dailyStats\\n    ...StatsPostChart_dailyEarnings\\n    __typename\\n  }\\n}\\n\\nfragment StatsPostChart_dailyStats on Post {\\n  dailyStats(startAt: $startAt, endAt: $endAt) {\\n    periodStartedAt\\n    views\\n    internalReferrerViews\\n    memberTtr\\n    __typename\\n  }\\n  __typename\\n  id\\n}\\n\\nfragment StatsPostChart_dailyEarnings on Post {\\n  earnings {\\n    dailyEarnings(startAt: $startAt, endAt: $endAt) {\\n      periodEndedAt\\n      periodStartedAt\\n      amount\\n      __typename\\n    }\\n    lastCommittedPeriodStartedAt\\n    __typename\\n  }\\n  __typename\\n  id\\n}\\n"}]' %(post)

graph_response = requests.post('https://medium.com/_/graphql', headers=headers, data=data)

# %%
print(graph_response.json())
# Out:
# [{'data': {'post': {'id': 'a3f3ed9d1f1e', 'dailyStats': [{'periodStartedAt': 1634083200000, 'views': 7, 'internalReferrerViews': 0, 'memberTtr': 0, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1634169600000, 'views': 7, 'internalReferrerViews': 3, 'memberTtr': 78, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1634256000000, 'views': 5, 'internalReferrerViews': 2, 'memberTtr': 2, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1634342400000, 'views': 169, 'internalReferrerViews': 12, 'memberTtr': 298, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1634428800000, 'views': 167, 'internalReferrerViews': 11, 'memberTtr': 42, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1634515200000, 'views': 40, 'internalReferrerViews': 2, 'memberTtr': 0, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1634601600000, 'views': 26, 'internalReferrerViews': 1, 'memberTtr': 0, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1634688000000, 'views': 12, 'internalReferrerVie
# ...

# %%
import datetime

# %%
graph_stats = graph_response.json()
print(graph_stats[0]['data']['post']['dailyStats'])
print(graph_stats[0]['data']['post']['earnings']['dailyEarnings'])
views = 0
internal_views = 0
time_sec = 0
for stat in graph_stats[0]['data']['post']['dailyStats']:
  views += stat['views']
  internal_views += stat['internalReferrerViews']
  time_sec += stat['memberTtr']

amount = 0
for earn in graph_stats[0]['data']['post']['earnings']['dailyEarnings']:
  amount += earn['amount']

print("Total Views :", views)
print("Internal Views :", internal_views)
print("External views :", views-internal_views)
print(time_sec)
print("Member Reading Time :", str(datetime.timedelta(seconds=time_sec)))
print(" Earnings : $" + str(amount/100))
# Out:
# [{'periodStartedAt': 1632873600000, 'views': 44, 'internalReferrerViews': 4, 'memberTtr': 428, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1632960000000, 'views': 109, 'internalReferrerViews': 11, 'memberTtr': 92, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1633046400000, 'views': 63, 'internalReferrerViews': 16, 'memberTtr': 91, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1633132800000, 'views': 30, 'internalReferrerViews': 3, 'memberTtr': 165, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1633219200000, 'views': 17, 'internalReferrerViews': 0, 'memberTtr': 0, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1633305600000, 'views': 17, 'internalReferrerViews': 2, 'memberTtr': 39, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1633392000000, 'views': 12, 'internalReferrerViews': 1, 'memberTtr': 13, '__typename': 'DailyPostStat'}, {'periodStartedAt': 1633478400000, 'views': 11, 'internalReferrerViews': 3, 'memberTtr': 0, '__typename': 'DailyPostSt
# ...

# %%
headers = {
    'authority': 'medium.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'x-client-date': '1640112442098',
    'x-xsrf-token': '056857f297ec',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'content-type': 'application/json',
    'accept': 'application/json',
    'x-obvious-cid': 'web',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://medium.com/me/stats',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '_ga=GA1.2.210810033.1625120447; g_state={"i_p":1632563953180,"i_l":4}; ext_name=ojplmecpdpgccookcobabopnaifgidhf; uid=1556949f4866; sid=1:pcTncp/CXXfmojWNZ4q8TirwESQUCkjAcdDmxNmpNf8k3YbdB5uXtlPVmZOBb2fx; optimizelyEndUserId=1556949f4866; nonce=1S1eCrug; lightstep_guid/medium-web=3cc34e131f079169; lightstep_session_id=85c9834b02a59f30; sz=1833; pr=1; tz=-330; xsrf=056857f297ec; _gid=GA1.2.1589521631.1640094626; __cfruid=3873bb2170a846970fedf53ecfb5dbd923c62d88-1640112249; _dd_s=rum=0&expire=1640113316148; _gat=1',
}

params = (
    ('limit', '250'),
    ('filter', 'not-response'),
    ('bucketType', 'MONTH'),
)

response = requests.get('https://medium.com/@colearninglounge/stats', headers=headers, params=params)

# %%
import json
from pprint import pprint
res = json.loads(response.text[16:])
print(res["payload"])
#print(response.json())
# res = response.text[17:]
# pprint(res)
# print(json.dumps(res))
# res = json.dumps(res)
# final_res = json.loads(res)
# print(type(final_res))
#pprint(final_res)
for pay in res["payload"]["value"]:
  print(pay["postId"])
# Out:
# {'value': [{'postId': 'a3f3ed9d1f1e', 'slug': '6-web-series-based-on-ai-you-should-binge-watch-today-if-you-are-an-ai-enthusiast-updated-list', 'previewImage': {'id': '1*VyHtmHCXIVPuQ9mJ4pTjXg.png', 'originalWidth': 2175, 'originalHeight': 537, 'isFeatured': True}, 'title': '6 Web-series Based on AI You Should Binge-Watch Today If You Are an AI Enthusiast [Updated List]', 'creatorId': '1556949f4866', 'collectionId': 'd9ca84c5ec5e', 'upvotes': 7, 'views': 657, 'reads': 156, 'createdAt': 1634111413706, 'firstPublishedAt': 1634111971101, 'visibility': 2, 'firstPublishedAtBucket': 'October 2021', 'readingTime': 5, 'syndicatedViews': 0, 'claps': 103, 'updateNotificationSubscribers': 0, 'isSeries': False, 'internalReferrerViews': 65, 'friendsLinkViews': 56, 'type': 'PostStat'}, {'postId': '6a8875a9fa7d', 'slug': 'power-bi-vs-tableau-which-one-is-better-the-analyst-perspective', 'previewImage': {'id': '0*LSOr2E0zH5GgW-BY.png', 'originalWidth': 2000, 'originalHeight': 1047, 'isFeatured': Tru
# ...
